# %%
import re
from collections import Counter

# %%
# function to tokenise words
def words(document):
    "Convert text to lower case and tokenise the document"
    return re.findall(r'\w+', document.lower())

# %%
# create a frequency table of all the words of the document
all_words = Counter(words(open('big.txt').read()))

# %%
# check frequency of a random word, say, 'chair'
all_words['chair']
# Out:
# 135

# %%
# look at top 10 frequent words
all_words.most_common(10)
# Out:
# [('the', 79809),
#  ('of', 40024),
#  ('and', 38312),
#  ('to', 28765),
#  ('in', 22023),
#  ('a', 21124),
#  ('that', 12512),
#  ('he', 12401),
#  ('was', 11410),
#  ('it', 10681)]

# %%
def edits_one(word):
    "Create all edits that are one edit away from `word`."
    alphabets    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])                   for i in range(len(word) + 1)]
    deletes    = [left + right[1:]                       for left, right in splits if right]
    inserts    = [left + c + right                       for left, right in splits for c in alphabets]
    replaces   = [left + c + right[1:]                   for left, right in splits if right for c in alphabets]
    transposes = [left + right[1] + right[0] + right[2:] for left, right in splits if len(right)>1]
    return set(deletes + inserts + replaces + transposes)

# %%
def edits_two(word):
    "Create all edits that are two edits away from `word`."
    return (e2 for e1 in edits_one(word) for e2 in edits_one(e1))

# %%
def known(words):
    "The subset of `words` that appear in the `all_words`."
    return set(word for word in words if word in all_words)

# %%
def possible_corrections(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits_one(word)) or known(edits_two(word)) or [word])

# %%
def prob(word, N=sum(all_words.values())): 
    "Probability of `word`: Number of appearances of 'word' / total number of tokens"
    return all_words[word] / N

# %%
print(len(set(edits_one("monney"))))
print(edits_one("monney"))
# Out:
# ['amonney', 'bmonney', 'cmonney', 'dmonney', 'emonney', 'fmonney', 'gmonney', 'hmonney', 'imonney', 'jmonney', 'kmonney', 'lmonney', 'mmonney', 'nmonney', 'omonney', 'pmonney', 'qmonney', 'rmonney', 'smonney', 'tmonney', 'umonney', 'vmonney', 'wmonney', 'xmonney', 'ymonney', 'zmonney', 'maonney', 'mbonney', 'mconney', 'mdonney', 'meonney', 'mfonney', 'mgonney', 'mhonney', 'mionney', 'mjonney', 'mkonney', 'mlonney', 'mmonney', 'mnonney', 'moonney', 'mponney', 'mqonney', 'mronney', 'msonney', 'mtonney', 'muonney', 'mvonney', 'mwonney', 'mxonney', 'myonney', 'mzonney', 'moanney', 'mobnney', 'mocnney', 'modnney', 'moenney', 'mofnney', 'mognney', 'mohnney', 'moinney', 'mojnney', 'moknney', 'molnney', 'momnney', 'monnney', 'moonney', 'mopnney', 'moqnney', 'mornney', 'mosnney', 'motnney', 'mounney', 'movnney', 'mownney', 'moxnney', 'moynney', 'moznney', 'monaney', 'monbney', 'moncney', 'mondney', 'moneney', 'monfney', 'mongney', 'monhney', 'moniney', 'monjney', 'monkney', 'monlney', 'monmney', 'monnney', 'mononey', 'monpney', 'monqney', 'monrney', 'monsney', 'montney', 'mon
yh', 'monneq', 'monnea', 'monuney', 'monxey', 'oonney', 'monnzey', 'monneny', 'mmnney', 'monneyv', 'monnee', 'monnei', 'monndy', 'monrney', 'monnney', 'monnpey', 'mponney', 'monneyr', 'monnxey', 'monley', 'motnney', 'jmonney', 'monfney', 'monner', 'mionney', 'monneyl', 'moncney', 'monvey', 'gmonney', 'mobney', 'modnney', 'xonney', 'monnyy', 'monnet', 'onney', 'kmonney', 'mronney', 'monnoy', 'mnoney', 'xmonney', 'mbnney', 'bmonney', 'jonney', 'monneyc', 'monneyd', 'amonney', 'modney', 'mznney', 'morney', 'monnec', 'mnney', 'mvonney', 'mongey', 'mhonney', 'monneuy', 'monjney', 'mohney', 'manney', 'monnkey', 'monsney', 'moiney', 'nmonney', 'moynney', 'mzonney', 'mtnney', 'monneg', 'mpnney', 'myonney', 'moniey', 'motney', 'monnaey', 'moanney', 'monnry', 'monneyu', 'monne', 'moneny', 'mounney', 'mqnney', 'mgonney', 'moncey', 'mfnney', 'monnejy', 'monnezy', 'moinney', 'monnecy', 'monfey', 'honney', 'monnel', 'monnewy', 'monnexy', 'mojnney', 'mbonney', 'monzney', 'fmonney', 'mondney', 'mnnney', 'wonney', 'movney', 'monbey', 'monnevy', 'tonney', 'monaney', 'moeney', 'monnay', 'monhey', 'monncey', 'monpney', 'monnsy', 'wmonney', 'money', 'monneyy', 'munney', 'movnney', 'monjey', 'monnepy', 'tmonney', 'monnjey', 'conney', 'monny', 'monbney', 'nonney', 'mkonney', 'mowney', 'mornney', 'monnby', 'monnyey', 'monniy', 'mosnney', 'monnly', 'monndey', 'ionney', 'yonney', 'mrnney', 'monkey', 'montey', 'monqney', 'montney', 'monneay', 'mongney', 'monrey', 'monneyq', 'uonney', 'monnuy', 'zmonney', 'monmey', 'gonney', 'mofney', 'monnbey', 'moknney', 'monniey', 'zonney', 'monneu', 'monnefy', 'monnty', 'lmonney', 'monnny'}

# %%
print(known(edits_one("monney")))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at words that are two edits away
print(len(set(edits_two("monney"))))
print(known(edits_one("monney")))
# Out:
# 51013
# {'money', 'monkey'}

# %%
# Let's look at possible corrections of a word
print(possible_corrections("monney"))
# Out:
# {'money', 'monkey'}

# %%
def prob(word, N=sum(all_words.values())): 
    "Probability of `word`: Number of appearances of 'word' / total number of tokens"
    return all_words[word] / N

# %%
def known(words):
    "The subset of `words` that appear in the `all_words`."
    return set(word for word in words if word in all_words)

# %%
# Let's look at probability of a word
print(prob("money"))
print(prob("monkey"))
# Out:
# 0.0002922233626303688
# 5.378344097491451e-06

# %%
def spell_check(word):
    "Print the most probable spelling correction for `word` out of all the `possible_corrections`"
    correct_word = max(possible_corrections(word), key=prob)
    if correct_word != word:
        return "Did you mean " + correct_word + "?"
    else:
        return "Correct spelling."

# %%
# test spell check
print(spell_check("monney"))
# Out:
# Did you mean money?
